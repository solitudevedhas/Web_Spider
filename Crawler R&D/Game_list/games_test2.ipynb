# %%
import requests
import json
import pandas as pd

# %%
url ='https://u3b6gr4ua3-dsn.algolia.net/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20vanilla%20JavaScript%20(lite)%203.22.1%3BJS%20Helper%202.20.1&x-algolia-application-id=U3B6GR4UA3&x-algolia-api-key=9a20c93440cf63cf1a7008d75f7438bf'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36'}

# %%
params = {
'x-algolia-agent': 'Algolia for vanilla JavaScript (lite) 3.22.1;JS Helper 2.20.1',
'x-algolia-application-id': 'U3B6GR4UA3',
'x-algolia-api-key': '9a20c93440cf63cf1a7008d75f7438bf'}

# %%
data = {"requests":[{"indexName":"noa_aem_game_en_us","params":"query=&hitsPerPage=4247&maxValuesPerFacet=30&page=0&tagFilters="}]}

# %%
jsondata = json.dumps(data)

# %%
jsonObj = requests.post(url, data=jsondata, params=params).json()

# %%
type(jsonObj)
# Out:
# dict

# %%
all_data=jsonObj['results'][0]['hits']

# %%
# Out:
#      type locale                                                url  \
# 0    game  en_US  /games/detail/animal-crossing-new-horizons-switch
# 1    game  en_US  /games/detail/tokyo-mirage-sessions-fe-encore-...
# 2    game  en_US                /games/detail/pokemon-shield-switch
# 3    game  en_US  /games/detail/pokemon-sword-and-pokemon-shield...
# 4    game  en_US                 /games/detail/pokemon-sword-switch
# ..    ...    ...                                                ...
# 995  game  en_US                     /games/detail/rogue-bit-switch
# 996  game  en_US              /games/detail/pixelmaker-studio-wii-u
# 997  game  en_US                   /games/detail/horror-stories-3ds
# 998  game  en_US      /games/detail/super-phantom-cat-remake-switch
# 999  game  en_US  /games/detail/azure-saga-pathfinder-deluxe-edi...
#
#                                           title  \
# 0                 Animal Crossing: New Horizons
# 1             Tokyo Mirage Sessions™ #FE Encore
# 2                                Pokémon Shield
# 3    Pokémon Sword & Pokémon Shield Double Pack
# 4                                 Pokémon Sword
# ..                                          ...
# 995                                   Rogue Bit
# 996                           PixelMaker Studio
# 997                              Horror Stories
# 998                   Super Phantom Cat: Remake
# 999       Azure Saga: Pathfinder DELUXE Edition
#
#                                            description   lastModified  \
# 0    If the hustle and bustle of modern life’s got ...  1569957018124
# 1    The worlds of the Fire Emblem™ series and Atlu...  1569957018124
# 2    For a limited time, players of the digital ver...  1569957018124
# 3    If you purchase the Pokémon™ Sword and Pokémon...  1569957018124
# 4    For a limited time, players of the digital ver...  1569957018124
# ..                                                 ...            ...
# 995  A single bit of computer memory became sentien...  1569957018124
# 996  PixelMaker Studio is a drawing program designe...  1569957018124
# 997  How did you imagine how murders are being comm...  1570119002718
# 998  Super Phantom Cat is a &quot;Pawsome&quot; ret...  1569957018124
# 999  Far into the future, the human race survives t...  1569957018124
#
#                                                   slug  \
# 0                  animal-crossing-new-horizons-switch
# 1               tokyo-mirage-sessions-fe-encore-switch
# 2                                pokemon-shield-switch
# 3    pokemon-sword-and-pokemon-shield-double-pack-s...
# 4                                 pokemon-sword-switch
# ..                                                 ...
# 995                                   rogue-bit-switch
# 996                            pixelmaker-studio-wii-u
# 997                                 horror-stories-3ds
# 998                    super-phantom-cat-remake-switch
# 999        azure-saga-pathfinder-deluxe-edition-switch
#
#                                                 boxArt  \
# 0    /content/dam/noa/en_US/games/switch/a/animal-c...
# 1    /content/dam/noa/en_US/games/switch/t/tokyo-mi...
# 2    /content/dam/noa/en_US/games/switch/p/pokemon-...
# 3    /content/dam/noa/en_US/games/switch/p/pokemon-...
# 4    /content/dam/noa/en_US/games/switch/p/pokemon-...
# ..                                                 ...
# 995  /content/dam/noa/en_US/games/switch/r/rogue-bi...
# 996  /content/dam/noa/en_US/games/wii-u/p/pixelmake...
# 997  /content/dam/noa/en_US/games/3ds/h/horror-stor...
# 998  /content/dam/noa/en_US/games/switch/s/super-ph...
# 999  /content/dam/noa/en_US/games/switch/a/azure-sa...
#
#                                                gallery         platform  ...  \
# 0    /content/dam/noa/en_US/games/switch/a/animal-c...  Nintendo Switch  ...
# 1    /content/dam/noa/en_US/games/switch/t/tokyo-mi...  Nintendo Switch  ...
# 2                     9mY3N3aDE6IY2fw-uqRfzBpSw2iah-wn  Nintendo Switch  ...
# 3                     9mY3N3aDE6IY2fw-uqRfzBpSw2iah-wn  Nintendo Switch  ...
# 4                     9mY3N3aDE6IY2fw-uqRfzBpSw2iah-wn  Nintendo Switch  ...
# ..                                                 ...              ...  ...
# 995                   EyMjllaDE6VWsdfyjUyOoBfCHKcOIzUv  Nintendo Switch  ...
# 996  /content/dam/noa/en_US/games/wii-u/p/pixelmake...            Wii U  ...
# 997                   NheTZmaDE6PTln0RKnpbZ1-guES_-V35     Nintendo 3DS  ...
# 998  /content/dam/noa/en_US/games/switch/s/super-ph...  Nintendo Switch  ...
# 999                   Z4MTllaDE6w7hDUgOBLwyqZffIkl3LQ0  Nintendo Switch  ...
#
#     freeToStart                 availability  \
# 0         False                [Coming soon]
# 1         False  [Pre-purchase, Coming soon]
# 2         False                [Coming soon]
# 3         False                [Coming soon]
# 4         False                [Coming soon]
# ..          ...                          ...
# 995       False              [Available now]
# 996       False              [Available now]
# 997       False              [Available now]
# 998       False              [Available now]
# 999       False              [Available now]
#
#                                  objectID  \
# 0    d5414092-e1f0-31ee-80b9-0a2a13ff3a4e
# 1    846084ed-a1f8-338e-805f-560b0a080395
# 2    b7995f41-31fb-3947-b128-4b322f0b07d0
# 3    9d0f385c-06a6-3a0e-b91e-1441422b0ee3
# 4    4cefd8b9-b98a-301f-8e88-abe6e1a54e26
# ..                                    ...
# 995  d2bd6474-03c5-375b-812d-6309f61f66fc
# 996  ac9d83f7-b0de-3d95-a5bf-e7c44172fed3
# 997  a3b7d846-cf7d-3422-9a6d-81fddef8ff77
# 998  7b1a5ba7-af5b-3c51-9558-a821c2fb00f2
# 999  7a946865-d2c6-3cc0-a177-6c4aee9f9cb3
#
#                                       _highlightResult           nsuid  \
# 0    {'title': {'value': 'Animal Crossing: New Hori...             NaN
# 1    {'title': {'value': 'Tokyo Mirage Sessions™ #F...  70010000022886
# 2    {'title': {'value': 'Pokémon Shield', 'matchLe...  70010000004492
# 3    {'title': {'value': 'Pokémon Sword & Pokémon S...             NaN
# 4    {'title': {'value': 'Pokémon Sword', 'matchLev...  70010000004496
# ..                                                 ...             ...
# 995  {'title': {'value': 'Rogue Bit', 'matchLevel':...  70010000018132
# 996  {'title': {'value': 'PixelMaker Studio', 'matc...  20010000027307
# 997  {'title': {'value': 'Horror Stories', 'matchLe...  50010000047335
# 998  {'title': {'value': 'Super Phantom Cat: Remake...  70010000016280
# 999  {'title': {'value': 'Azure Saga: Pathfinder DE...  70010000014773
#
#        msrp  priceRange salePrice                                id hasPT
# 0       NaN         NaN       NaN                               NaN   NaN
# 1     59.99        $40+       NaN                               NaN   NaN
# 2     59.99        $40+       NaN  mmdmDFdNT8GZaGcqWQm4ehgm7kMAUWcJ   NaN
# 3    119.99         NaN       NaN                               NaN   NaN
# 4     59.99        $40+       NaN  VpTxFaZkFQn0D5bYJYtkFzbmLZJjFpC1   NaN
# ..      ...         ...       ...                               ...   ...
# 995    4.99  $0 - $4.99       NaN  bO2_kbjEKl30ik4epzLteU8Mj8IO622t   NaN
# 996    9.99  $5 - $9.99       NaN  dDK4Eo9mQPN13Jb3bVWv_XUbnj1TW46J   NaN
# 997    3.99  $0 - $4.99       NaN  05-dp76H9hvyBlQZEE1kFnRxny728bfM   NaN
# 998    9.99  $5 - $9.99       NaN                               NaN   NaN
# 999    9.99  $5 - $9.99       NaN  yfUZO3CLfhC0bJPlEg4anICjqVtjflKZ   NaN
#
# [1000 rows x 33 columns]
